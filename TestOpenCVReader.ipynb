# %%
import numpy as np
from OpenCVReader import OpenCVReader
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import cv2
# %matplotlib inline

# %%
imgfile = '/mnt/chenkq/data/GSet/trainset/10_top.tif'

# %%
reader = OpenCVReader(imgfile)

# %%
img = reader.readPatchAsNumpy(startx=-500,starty=-500,width=1000,height=1000,bandlst=[],dtype=np.uint8,
                              hwcorder=True,converter=None)

# %%
plt.imshow(img,cmap=cm.bwr)

# %%
plt.imshow(img,cmap=cm.bwr)

# %%
cv2.imwrite('/mnt/chenkq/testopencvreader.jpg',img)
# Out:
# True

# %%
xx =(0,1,1,2,3,4,5,6)

# %%
print np.asarray(xx[1:])
# Out:
# [1 1 2 3 4 5 6]

# %%
print list(np.asarray((tuple(xx)))/2)
# Out:
# [0, 0, 0, 1, 1, 2, 2, 3]

# %%
import random

# %%
random.sample(xx,20)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-5b346e1e304d> in <module>()
# ----> 1 random.sample(xx,20)[0]
#
# /home/chenkq/anaconda2/lib/python2.7/random.pyc in sample(self, population, k)
#     321         n = len(population)
#     322         if not 0 <= k <= n:
# --> 323             raise ValueError("sample larger than population")
#     324         random = self.random
#     325         _int = int
#
# ValueError: sample larger than population

# %%
xx ={}
xx['app'] = [1,2,3,4,5,6]
xx['pear'] = (1,2,4)

# %%
print xx.items()
# Out:
# [('app', [1, 2, 3, 4, 5, 6]), ('pear', (1, 2, 4))]

# %%
from PIL import Image

# %%
f = '/mnt/chenkq/data/vaihingenBuilding/trainset/gt/top_mosaic_09cm_area26.tif'

# %%
imgcv = cv2.imread(f,-1)

# %%
plt.imshow(imgcv)

# %%
print imgcv.shape
# Out:
# (2569, 1919)

# %%
pil = Image.open(f)

# %%
xx =  pil.size
print xx
# Out:
# (1919, 2569)

# %%
print (xx[1],xx[0])
# Out:
# (2569, 1919)

# %%
list((5,))
# Out:
# [5]
